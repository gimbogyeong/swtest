# %% [markdown]
# # 1- Array

# %% [markdown]
# 1470. Shuffle the Array
#
# Given the array nums consisting of 2n elements in the form [x1,x2,...,xn,y1,y2,...,yn].
#
# Return the array in the form [x1,y1,x2,y2,...,xn,yn].
#
# Input: nums = [2,5,1,3,4,7], n = 3
# Output: [2,3,5,4,1,7]
# Explanation: Since x1=2, x2=5, x3=1, y1=3, y2=4, y3=7 then the answer is [2,3,5,4,1,7].
#
# https://leetcode.com/problems/shuffle-the-array/description/

# %%
class Solution {
public:
    vector<int> shuffle(vector<int>& nums, int n) {
        vector <int> ans; 

        for (int i = 0 ; i<n ; i++){
            ans.push_back(nums[i]);
            ans.push_back(nums[i+n]);
        }

        return ans; 
    }
};

# %%
vector<int> nums = {2,5,1,3,4,7};
int n = 4; 

Solution solve;
vector<int> ret = solve.shuffle(nums ,n);

for (auto val : ret ) {
    cout << val << ' ';
}
cout << endl;

# %% [markdown]
# 1471

# %%
class Solution {
public:
    vector<int> shuffle(vector<int>& nums, int n) {
        vector <int> ans; 

        for (int i = 0 ; i<n ; i++){
            ans.push_back(nums[i]);
            ans.push_back(nums[i+n]);
        }

        return ans; 
    }
};

# %%
vector<int> nums = {0,2,1,5,3,4};

Solution solve;
vector<int> ret = solve.shuffle( nums );

for (auto val : ret ) {
    cout << val << ' ';
}
cout << endl;
# Out:
# leetcode.cpp  sample_data

# %%
# %%shell
# g++ leetcode.cpp -o
# Out:
# leetcode.cpp:6:5: error: ‘vector’ does not name a type
#      vector<int> shuffle(vector<int>& nums, int n) {
#      ^~~~~~
# leetcode.cpp: In function ‘int main()’:
# leetcode.cpp:20:3: error: ‘vector’ was not declared in this scope
#    vector<int> nums = {0,2,1,5,3,4};
#    ^~~~~~
# leetcode.cpp:20:10: error: expected primary-expression before ‘int’
#    vector<int> nums = {0,2,1,5,3,4};
#           ^~~
# leetcode.cpp:23:10: error: expected primary-expression before ‘int’
#    vector<int> ret = solve.buildArray( nums );
#           ^~~
# leetcode.cpp:25:17: error: ‘ret’ was not declared in this scope
#  for (auto val : ret ) {
#                  ^~~
# leetcode.cpp:26:5: error: ‘cout’ was not declared in this scope
#      cout << val << ' ';
#      ^~~~
# leetcode.cpp:28:1: error: ‘cout’ was not declared in this scope
#  cout << endl;
#  ^~~~
# leetcode.cpp:28:9: error: ‘endl’ was not declared in this scope
#  cout << endl;
#          ^~~~
# leetcode.cpp:28:9: note: suggested alternative: ‘enum’
#  cout << endl;
#          ^~~~
#          enum
# /bin/bash: line 1: ./bout: No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-15-aa305189cb3c> in <module>
# ----> 1 get_ipython().run_cell_magic('shell', '', 'g++ leetcode.cpp -o bout\n./bout\n')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_system_commands.py in _shell_cell_magic(args, cmd)
#     107   result = _run_command(cmd, clear_streamed_output=False)
#     108   if not parsed_args.ignore_errors:
# --> 109     result.check_returncode()
#     110   return result
#     111
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_system_commands.py in check_returncode(self)
#     133     if self.returncode:
#     134       raise subprocess.CalledProcessError(
# --> 135           returncode=self.returncode, cmd=self.args, output=self.output)
#     136
#     137   def _repr_pretty_(self, p, cycle):  # pylint:disable=unused-argument
#
# CalledProcessError: Command 'g++ leetcode.cpp -o bout
# ./bout
# ' returned non-zero exit status 127.
